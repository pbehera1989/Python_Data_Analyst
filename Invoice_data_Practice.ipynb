# %%
import pandas as pd

# %%
Invoice_Data = pd.read_excel(r"C:\Users\pbehera\OneDrive - GXO\Desktop\Python\Practice\February 2022 Invoice Log.xlsx")

# %%
Invoice_Data
# Out:
#       GL Period  Profit Center                 Vertical  \
# 0    2022-02-01         413000                   Canada
# 1    2022-02-01         413000                   Canada
# 2    2022-02-01         413000                   Canada
# 3    2022-02-01         413000                   Canada
# 4    2022-02-01         413000                   Canada
# 5    2022-02-01         410440               Automotive
# 6    2022-02-01         410440               Automotive
# 7    2022-02-01         410560                 Chemical
# 8    2022-02-01         410428                   Direct
# 9    2022-02-01         410428                   Direct
# 10   2022-02-01         410428                   Direct
# 11   2022-02-01         410428                   Direct
# 12   2022-02-01         410428                   Direct
# 13   2022-02-01         410428                   Direct
# 14   2022-02-01         410428                   Direct
# 15   2022-02-01         410428                   Direct
# ...

# %%
Invoice_Data.head()
# Out:
#    GL Period  Profit Center Vertical Customer            Site  \
# 0 2022-02-01         413000   Canada       3M  3M - Milton ON
# 1 2022-02-01         413000   Canada       3M  3M - Milton ON
# 2 2022-02-01         413000   Canada       3M  3M - Milton ON
# 3 2022-02-01         413000   Canada       3M  3M - Milton ON
# 4 2022-02-01         413000   Canada       3M  3M - Milton ON
#
#                          Invoice Discription Invoice Number InvDraft Start  \
# 0  3M - Canada Operations - Labor - WEEKLY 1    41300022021     2022-02-02
# 1  3M - Canada Operations - Labor - WEEKLY 2    41300022022     2022-02-14
# 2  3M - Canada Operations - Labor - WEEKLY 3    41300022023     2022-02-21
# 3  3M - Canada Operations - Labor - WEEKLY 4    41300022024     2022-02-28
# 4         3M - Canada Operations - Month End    41300022025     2022-03-01
#
#   Invoice Due Date  Approval -  To Ops  Approval - Frm Ops  \
# 0       2022-02-08                 NaN                 NaN
# ...

# %%
Invoice_Data.shape
# Out:
# (1054, 32)

# %%
Invoice_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054 entries, 0 to 1053
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GL Period            1054 non-null   datetime64[ns]
#  1   Profit Center        1054 non-null   int64
#  2   Vertical             1054 non-null   object
#  3   Customer             1054 non-null   object
#  4   Site                 1054 non-null   object
#  5   Invoice Discription  1054 non-null   object
#  6   Invoice Number       1054 non-null   object
#  7   InvDraft Start       1054 non-null   datetime64[ns]
#  8   Invoice Due Date     1053 non-null   datetime64[ns]
#  9   Approval -  To Ops   0 non-null      float64
#  10  Approval - Frm Ops   0 non-null      float64
#  11  Approval - To Cust   0 non-null      float64
#  12  Approval - Frm Cust  0 non-null      float64
#  13  Final Inv Sent       0 non-null      float64
# ...

# %%
Invoice_Data.index
# Out:
# RangeIndex(start=0, stop=1054, step=1)

# %%
Invoice_Data.columns
# Out:
# Index(['GL Period', 'Profit Center', 'Vertical', 'Customer', 'Site',
#        'Invoice Discription', 'Invoice Number', 'InvDraft Start',
#        'Invoice Due Date', 'Approval -  To Ops', 'Approval - Frm Ops',
#        'Approval - To Cust', 'Approval - Frm Cust', 'Final Inv Sent',
#        'Invoice Amount', 'Status', 'Frequency', 'Pay Term (Days)',
#        'Invoice Type', 'From Date', 'To Date', 'Resp Analyst', 'Resp Manager',
#        'Notes', 'Ops Contact', 'AP Target', 'Error_Check', 'Expected_Start',
#        'Invoice_ID', 'Division', 'TAX ID', 'Customer_Code'],
#       dtype='object')

# %%
Invoice_Data.dtypes
# Out:
# GL Period              datetime64[ns]
# Profit Center                   int64
# Vertical                       object
# Customer                       object
# Site                           object
# Invoice Discription            object
# Invoice Number                 object
# InvDraft Start         datetime64[ns]
# Invoice Due Date       datetime64[ns]
# Approval -  To Ops            float64
# Approval - Frm Ops            float64
# Approval - To Cust            float64
# Approval - Frm Cust           float64
# Final Inv Sent                float64
# Invoice Amount                  int64
# Status                        float64
# Frequency                      object
# Pay Term (Days)                 int64
# Invoice Type                  float64
# From Date              datetime64[ns]
# To Date                datetime64[ns]
# Resp Analyst                   object
# Resp Manager                   object
# Notes                         float64
# Ops Contact                   float64
# ...

# %%
pd.set_option('display.max_column',None)

# %%
pd.set_option('display.max_row',None)

# %%
Invoice_Data.head(2)
# Out:
#    GL Period  Profit Center Vertical Customer            Site  \
# 0 2022-02-01         413000   Canada       3M  3M - Milton ON
# 1 2022-02-01         413000   Canada       3M  3M - Milton ON
#
#                          Invoice Discription Invoice Number InvDraft Start  \
# 0  3M - Canada Operations - Labor - WEEKLY 1    41300022021     2022-02-02
# 1  3M - Canada Operations - Labor - WEEKLY 2    41300022022     2022-02-14
#
#   Invoice Due Date  Approval -  To Ops  Approval - Frm Ops  \
# 0       2022-02-08                 NaN                 NaN
# 1       2022-02-15                 NaN                 NaN
#
#    Approval - To Cust  Approval - Frm Cust  Final Inv Sent  Invoice Amount  \
# 0                 NaN                  NaN             NaN               0
# 1                 NaN                  NaN             NaN               0
#
#    Status Frequency  Pay Term (Days)  Invoice Type  From Date    To Date  \
# ...

# %%
Invoice_Data["Resp Manager"].unique()
# Out:
# array(['A Chetty', 'A Jariwala', 'S Bowen', 'K Williard', 'S Christensen',
#        'M Hull', 'K Cochran', 'D Nardi', 'D Chukwuemeka'], dtype=object)

# %%
Invoice_Data.nunique()
# Out:
# GL Period                 1
# Profit Center           267
# Vertical                 13
# Customer                153
# Site                    236
# Invoice Discription    1051
# Invoice Number         1052
# InvDraft Start           10
# Invoice Due Date          8
# Approval -  To Ops        0
# Approval - Frm Ops        0
# Approval - To Cust        0
# Approval - Frm Cust       0
# Final Inv Sent            0
# Invoice Amount            1
# Status                    0
# Frequency                 3
# Pay Term (Days)          13
# Invoice Type              0
# From Date                 6
# To Date                   6
# Resp Analyst             34
# Resp Manager              9
# Notes                     0
# Ops Contact               0
# AP Target                 0
# Error_Check               0
# Expected_Start           10
# Invoice_ID             1052
# Division                  5
# TAX ID                  147
# Customer_Code           183
# dtype: int64

# %%
Invoice_Data['Resp Analyst'].value_counts()
# Out:
# R Luther         150
# G Debow          104
# G Sabin           98
# D Bhome           77
# L Pinney          50
# S Wilfong         50
# M Sawant          48
# A Pradhan         46
# A Ghevade         38
# S Strobel         36
# N Talreja         35
# P Behera          33
# J Payne           33
# R Singh           32
# R More            28
# R Bellel          28
# J Shinde          27
# V Kesaria         26
# C Mason           24
# T Person          20
# K Nutter          16
# C Boggs            8
# T Dunnigan         8
# H Li               7
# R Smith            5
# T Hayes            5
# S Christensen      5
# K Freeman          5
# A Bobade           4
# M Tawade           2
# M Daware           2
# R Dyakov           2
# M Hull             1
# T Snyder           1
# Name: Resp Analyst, dtype: int64

# %%
Invoice_Data['Resp Analyst'].nunique()
# Out:
# 34

# %%
Invoice_Data['Resp Manager'].unique()
# Out:
# array(['A Chetty', 'A Jariwala', 'S Bowen', 'K Williard', 'S Christensen',
#        'M Hull', 'K Cochran', 'D Nardi', 'D Chukwuemeka'], dtype=object)

# %%
Invoice_Data.head(2)
# Out:
#    GL Period  Profit Center Vertical Customer            Site  \
# 0 2022-02-01         413000   Canada       3M  3M - Milton ON
# 1 2022-02-01         413000   Canada       3M  3M - Milton ON
#
#                          Invoice Discription Invoice Number InvDraft Start  \
# 0  3M - Canada Operations - Labor - WEEKLY 1    41300022021     2022-02-02
# 1  3M - Canada Operations - Labor - WEEKLY 2    41300022022     2022-02-14
#
#   Invoice Due Date  Approval -  To Ops  Approval - Frm Ops  \
# 0       2022-02-08                 NaN                 NaN
# 1       2022-02-15                 NaN                 NaN
#
#    Approval - To Cust  Approval - Frm Cust  Final Inv Sent  Invoice Amount  \
# 0                 NaN                  NaN             NaN               0
# 1                 NaN                  NaN             NaN               0
#
#    Status Frequency  Pay Term (Days)  Invoice Type  From Date    To Date  \
# ...

# %%
Invoice_Data[(Invoice_Data['Resp Analyst'] == 'P Behera') | (Invoice_Data['Frequency'] == 'Weekly')]
# Out:
#       GL Period  Profit Center                 Vertical  \
# 0    2022-02-01         413000                   Canada
# 1    2022-02-01         413000                   Canada
# 2    2022-02-01         413000                   Canada
# 3    2022-02-01         413000                   Canada
# 8    2022-02-01         410428                   Direct
# 9    2022-02-01         410428                   Direct
# 10   2022-02-01         410428                   Direct
# 11   2022-02-01         410428                   Direct
# 12   2022-02-01         410428                   Direct
# 13   2022-02-01         410428                   Direct
# 14   2022-02-01         410428                   Direct
# 15   2022-02-01         410428                   Direct
# 18   2022-02-01         410429                   Direct
# 19   2022-02-01         410429                   Direct
# 20   2022-02-01         410429                   Direct
# 21   2022-02-01         410429                   Direct
# ...

# %%
Invoice_Data[Invoice_Data['Resp Analyst'] == 'R More']
# Out:
#      GL Period  Profit Center         Vertical                Customer  \
# 0   2022-02-01         413000           Canada                      3M
# 1   2022-02-01         413000           Canada                      3M
# 2   2022-02-01         413000           Canada                      3M
# 3   2022-02-01         413000           Canada                      3M
# 4   2022-02-01         413000           Canada                      3M
# 8   2022-02-01         410428           Direct  Allied Air Enterprises
# 9   2022-02-01         410428           Direct  Allied Air Enterprises
# 10  2022-02-01         410428           Direct  Allied Air Enterprises
# 11  2022-02-01         410428           Direct  Allied Air Enterprises
# 12  2022-02-01         410428           Direct  Allied Air Enterprises
# 13  2022-02-01         410428           Direct  Allied Air Enterprises
# 14  2022-02-01         410428           Direct  Allied Air Enterprises
# ...

# %%
Invoice_Data.head(2)
# Out:
#    GL Period  Profit Center Vertical Customer            Site  \
# 0 2022-02-01         413000   Canada       3M  3M - Milton ON
# 1 2022-02-01         413000   Canada       3M  3M - Milton ON
#
#                          Invoice Discription Invoice Number InvDraft Start  \
# 0  3M - Canada Operations - Labor - WEEKLY 1    41300022021     2022-02-02
# 1  3M - Canada Operations - Labor - WEEKLY 2    41300022022     2022-02-14
#
#   Invoice Due Date  Approval -  To Ops  Approval - Frm Ops  \
# 0       2022-02-08                 NaN                 NaN
# 1       2022-02-15                 NaN                 NaN
#
#    Approval - To Cust  Approval - Frm Cust  Final Inv Sent  Invoice Amount  \
# 0                 NaN                  NaN             NaN               0
# 1                 NaN                  NaN             NaN               0
#
#    Status Frequency  Pay Term (Days)  Invoice Type  From Date    To Date  \
# ...

# %%
Invoice_Data.groupby('Resp Analyst').sum()
# Out:
#                Profit Center  Approval -  To Ops  Approval - Frm Ops  \
# Resp Analyst
# A Bobade             1642426                 0.0                 0.0
# A Ghevade           15599361                 0.0                 0.0
# A Pradhan           18879797                 0.0                 0.0
# C Boggs              3283916                 0.0                 0.0
# C Mason              9849890                 0.0                 0.0
# D Bhome             31587531                 0.0                 0.0
# G Debow             42710152                 0.0                 0.0
# G Sabin             40182450                 0.0                 0.0
# H Li                 2874046                 0.0                 0.0
# J Payne             13539059                 0.0                 0.0
# J Shinde            11083725                 0.0                 0.0
# K Freeman            2053765                 0.0                 0.0
# ...
